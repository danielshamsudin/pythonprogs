# %%
import glob
from PIL import Image

images = glob.glob("C:/Users/danie/Documents/TPR/project/leftover/hlb cheng/*.jpg")
count = 1

for image in images:
    with open(image,'rb') as file:
        image = Image.open(file)
        image.save("C:/Users/danie/Documents/TPR/project/leftover/hlb cheng/" + str(count) + '.jpg')
        count += 1

# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread('C:/Users/danie/Documents/TPR/project/labelled/1.jpg')
print(img.shape)
# Out:
# (4032, 3024, 3)

# %%
import glob
from PIL import Image

images = glob.glob("C:/Users/danie/Documents/TPR/project/leftover/hlb cheng/*.jpg")
count = 1

for image in images:
    with open(image,'rb') as file:
        image = Image.open(file)
        image.thumbnail((1024,1024))
        image.save("C:/Users/danie/Documents/TPR/project/leftover/resized/" + str(count) + '.jpg')
        count += 1

# %%
num = '26'
img = cv2.imread('C:/Users/danie/Documents/TPR/project/leftover/resized/' + num + '.jpg')
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.show()
cropped = img[500:610,:]
plt.imshow(cv2.cvtColor(cropped,cv2.COLOR_BGR2RGB))
plt.show()
cv2.imwrite('C:/Users/danie/Documents/TPR/project/leftover/cropped/' + num + '.jpg',cropped)
# Out:
# True
